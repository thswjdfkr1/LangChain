# %% [markdown]
# # langchain으로 llm 호출

# %%
# !pip install langchain langchain-openai langchain-google-genai langchain-anthropic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.6/433.6 kB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.51
#     Uninstalling langchain-core-0.3.51:
#       Successfully uninstalled langchain-core-0.3.51
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# ...

# %%
from IPython.display import Markdown
import textwrap

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(text.wrap(text, '> ',predicate=lambda _:True))

# %% [markdown]
# ## open ai

# %%
from langchain_openai import ChatOpenAI

# %%
model = ChatOpenAI(model_name='gpt-4o')
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# <ipython-input-4-3f7a42830c32> in <cell line: 0>()
# ----> 1 model = ChatOpenAI(model_name='gpt-4o')
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/load/serializable.py in __init__(self, *args, **kwargs)
#     128     def __init__(self, *args: Any, **kwargs: Any) -> None:
#     129         """"""  # noqa: D419
# --> 130         super().__init__(*args, **kwargs)
#     131
#     132     @classmethod
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.11/dist-packages/langchain_openai/chat_models/base.py in validate_environment(self)
#     643                 )
#     644             sync_specific = {"http_client": self.http_client}
# --> 645             self.root_client = openai.OpenAI(**client_params, **sync_specific)  # type: ignore[arg-type]
# ...
